# %% [markdown]
# name: Marco Giunta

# %% [markdown]
# # Exercise 1: Scotland Lakes

# %%
library("tidyverse")
# Out:
# -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.0 --
#
# v ggplot2 3.3.3     v purrr   0.3.4
# v tibble  3.1.0     v dplyr   1.0.5
# v tidyr   1.1.3     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.1
#
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %% [markdown]
# ## 1.0) Loading the data
# First of all we load the data. Since I'm too lazy to manually input it and still pretty new to R I wrote a short python script to generate everything for us; by executing it the working folder will be populated with one csv file for each column of the dataframe.

# %%
# this executes a system command which one may type manually in the terminal
system("python laghi_Scozia_helper_script.py")
# depending on the user's OS it may be necessary to adjust the command e.g. by adding "3" after "python"; the only thing that matters is that the script is executed (even manually), though
# Out:
# [1] 0

# %%
# we can now actually read the data
scottish.lakes.volume <- read.csv("Volume.csv")
scottish.lakes.area <- read.csv("Area.csv")
scottish.lakes.length <- read.csv("Length.csv")
scottish.lakes.maxdepth <- read.csv("Max-depth.csv")
scottish.lakes.meandepth <- read.csv("Mean-depth.csv")

# we print one as an example
print(str(scottish.lakes.volume))
scottish.lakes.volume
# Out:
# 'data.frame':	13 obs. of  2 variables:
#  $ Loch  : chr  "Ness" "Lomond" "Morar" "Tay" ...
#  $ Volume: num  7.45 2.6 2.3 1.6 1.2 1.09 1.08 1.07 0.97 0.79 ...
# NULL
#    Loch    Volume
# 1  Ness    7.45
# 2  Lomond  2.60
# 3  Morar   2.30
# 4  Tay     1.60
# 5  Awe     1.20
# 6  Maree   1.09
# 7  Ericht  1.08
# 8  Lochy   1.07
# 9  Rannoch 0.97
# 10 Shiel   0.79
# 11 Katrine 0.77
# 12 Arkaig  0.75
# 13 Shin    0.35

# %%
# Thanks to str(...) we notice that the objects we just created are actually dataframes even though we want named vectors; 
# to fix this we create new vectors out of the above dataframes and set their names using the setNames function, where we
# once again exploit the dataframes to create the chr vector containing the names to be given to each num value

lake_names <- scottish.lakes.volume[[1]] # notice the [[]] operator, needed to extract a chr vector instead of a dataframe

volume <- setNames(scottish.lakes.volume[[2]],lake_names) # same here: [[]] is needed to obtain a num vector
area <- setNames(scottish.lakes.area[[2]],lake_names)
length <- setNames(scottish.lakes.length[[2]],lake_names)
maxdepth <- setNames(scottish.lakes.maxdepth[[2]],lake_names)
meandepth <- setNames(scottish.lakes.meandepth[[2]],lake_names)

# we print one as an example
print(str(volume))
volume
# Out:
#  Named num [1:13] 7.45 2.6 2.3 1.6 1.2 1.09 1.08 1.07 0.97 0.79 ...
#  - attr(*, "names")= chr [1:13] "Ness" "Lomond" "Morar" "Tay" ...
# NULL
#    Ness  Lomond   Morar     Tay     Awe   Maree  Ericht   Lochy Rannoch   Shiel
#    7.45    2.60    2.30    1.60    1.20    1.09    1.08    1.07    0.97    0.79
# Katrine  Arkaig    Shin
#    0.77    0.75    0.35

# %%
# We can now create the final dataframe starting from the named vectors. Notice that data.frame(...) automatically uses
# the names inside each vector to create the dataframe index instead of a separate "Loch" column
scottish.lakes <- data.frame(volume,area,length,maxdepth,meandepth)
column_names <- c("Volume (km^3)","Area (km^2)","Length (km)","Max depth (m)","Mean depth (m)")
scottish.lakes <- setNames(scottish.lakes,column_names)
scottish.lakes
# Out:
#         Volume (km^3) Area (km^2) Length (km) Max depth (m) Mean depth (m)
# Ness    7.45          56.0        39.0        230           132.0
# Lomond  2.60          71.0        36.0        190            37.0
# Morar   2.30          27.0        18.8        310            87.0
# Tay     1.60          26.4        23.0        150            60.6
# Awe     1.20          39.0        41.0         94            32.0
# Maree   1.09          28.6        20.0        114            38.0
# Ericht  1.08          18.6        23.0        156            57.6
# Lochy   1.07          16.0        16.0        162            70.0
# Rannoch 0.97          19.0        15.7        134            51.0
# Shiel   0.79          19.5        28.0        128            40.0
# Katrine 0.77          12.4        12.9        151            43.4
# Arkaig  0.75          16.0        19.3        109            46.5
# Shin    0.35          22.5        27.8         49            15.5

# %%
# As we already noted the above doesn't contain a "Loch" column, encoding that information in the index column
# (more precisely: in the row names). It's easy to modify our dataframe in such a way as to put the Loch col. in line with the
# others via the row.names function; since I like having "Loch" as the row names column I'm just going to create another dataframe.

#print(row.names(scottish.lakes))
scottish.lakes_loch_col <- scottish.lakes
scottish.lakes_loch_col$Loch <- row.names(scottish.lakes)
row.names(scottish.lakes_loch_col) <- NULL
scottish.lakes_loch_col <- scottish.lakes_loch_col[c("Loch",names(scottish.lakes))] # this moves the "Loch" col. to the left
scottish.lakes_loch_col
# Out:
#    Loch    Volume (km^3) Area (km^2) Length (km) Max depth (m) Mean depth (m)
# 1  Ness    7.45          56.0        39.0        230           132.0
# 2  Lomond  2.60          71.0        36.0        190            37.0
# 3  Morar   2.30          27.0        18.8        310            87.0
# 4  Tay     1.60          26.4        23.0        150            60.6
# 5  Awe     1.20          39.0        41.0         94            32.0
# 6  Maree   1.09          28.6        20.0        114            38.0
# 7  Ericht  1.08          18.6        23.0        156            57.6
# 8  Lochy   1.07          16.0        16.0        162            70.0
# 9  Rannoch 0.97          19.0        15.7        134            51.0
# 10 Shiel   0.79          19.5        28.0        128            40.0
# 11 Katrine 0.77          12.4        12.9        151            43.4
# 12 Arkaig  0.75          16.0        19.3        109            46.5
# 13 Shin    0.35          22.5        27.8         49            15.5

# %% [markdown]
# ## Data analysis

# %% [markdown]
# ### 1.1) min/max volume lake
# Functions `min` and `max` may be trivially used to find the maximum and minimum volume values by feeding them `scottish.lakes["Volume (km^3)"]` as argument. To find which lake these value correspond to we can either use `which.min`/`which.max` (which is the mathematical operation of $\text{argmin}$/$\text{argmax}$) to find the index of the minimum/maximum value or use logical indexing (other solutions may exist, of course; this are only two of the simplest).

# %%
#min
min.vol.value = min(scottish.lakes$`Volume (km^3)`)
min.vol.loch = row.names(scottish.lakes)[which.min(scottish.lakes$`Volume (km^3)`)]
#min.vol.loch = scottish.lakes_loch_col[scottish.lakes["Volume (km^3)"] == min.vol.value][1] # this is equivalent but longer to 
# write and a bit harder to read

message = c("The minimum lake volume is",min.vol.value,"km^3 and is achieved by Loch",min.vol.loch)
print(paste(message, collapse=" ", sep=" ")) # collapse is needed to achieve a single string instead of a chr vector

#max
max.vol.value = max(scottish.lakes$`Volume (km^3)`)
max.vol.loch = row.names(scottish.lakes)[which.max(scottish.lakes$`Volume (km^3)`)]
#max.vol.loch = scottish.lakes_loch_col[scottish.lakes["Volume (km^3)"] == max.vol.value][1] # this is equivalent but longer to 
# write and a bit harder to read

message = c("The maximum lake volume is",max.vol.value,"km^3 and is achieved by Loch",max.vol.loch)
print(paste(message, collapse=" ", sep=" "))
# Out:
# [1] "The minimum lake volume is 0.35 km^3 and is achieved by Loch Shin"
# [1] "The maximum lake volume is 7.45 km^3 and is achieved by Loch Ness"

# %% [markdown]
# ### 1.2) Arranging rows by area value
# We can use the `arrange` function from library `dplyr` to achieve the desired result.

# %%
# I'm changing the column names to a slightly less human-readable format to make typing/using functions easier.
names(scottish.lakes) <- c("volume","area","length","maxdepth","meandepth")
scottish.lakes_sorted_by_area <- arrange(scottish.lakes, desc(area)) # desc is needed to have descending order.
# Technically it's not necessary to sort by descending area, but it's easier to subset with [1] and [2] than 
# it is with [length(..)] or something similar

message <- c("The two lakes with the largest areas are",row.names(scottish.lakes_sorted_by_area)[1],
             "and",row.names(scottish.lakes_sorted_by_area)[2],"with area values",
             scottish.lakes_sorted_by_area$area[1],"and",scottish.lakes_sorted_by_area$area[2],"km^2 respectively")

print(paste(message, sep=" ", collapse=" "))
# Out:
# [1] "The two lakes with the largest areas are Lomond and Ness with area values 71 and 56 km^2 respectively"

# %% [markdown]
# ### 1.3) Summing area values
# To find the total area of Scotland covered by water we straightforwardly apply the sum function.

# %%
message <- c("The total area of Scotland covered by water is",sum(scottish.lakes$area),"km^2.")
print(paste(message, sep=" ", collapse=" "))
# Out:
# [1] "The total area of Scotland covered by water is 372 km^2."

# %% [markdown]
# # Exercise 2: oil prices

# %% [markdown]
# ## 2.1) Loading the data
# First we create a dataframe by downloading it directly from the web (I slightly modified the provided URL to make this possible)

# %%
url <- "https://drive.google.com/u/0/uc?id=1cUQ8d0kDOw2lmzMAHIPglpdcnHy4GgF3&export=download"
oil <- read.csv(url, skip=1) # the first row in the original document is just a comment and therefore we ignore it
oil
# Out:
#     Entity Code     Year OilPrice
# 1   World  OWID_WRL 1861 0.49
# 2   World  OWID_WRL 1862 1.05
# 3   World  OWID_WRL 1863 3.15
# 4   World  OWID_WRL 1864 8.06
# 5   World  OWID_WRL 1865 6.59
# 6   World  OWID_WRL 1866 3.74
# 7   World  OWID_WRL 1867 2.41
# 8   World  OWID_WRL 1868 3.63
# 9   World  OWID_WRL 1869 3.64
# 10  World  OWID_WRL 1870 3.86
# 11  World  OWID_WRL 1871 4.34
# 12  World  OWID_WRL 1872 3.64
# 13  World  OWID_WRL 1873 1.83
# 14  World  OWID_WRL 1874 1.17
# 15  World  OWID_WRL 1875 1.35
# 16  World  OWID_WRL 1876 2.56
# 17  World  OWID_WRL 1877 2.42
# 18  World  OWID_WRL 1878 1.19
# 19  World  OWID_WRL 1879 0.86
# 20  World  OWID_WRL 1880 0.95
# 21  World  OWID_WRL 1881 0.86
# 22  World  OWID_WRL 1882 0.78
# 23  World  OWID_WRL 1883 1.00
# 24  World  OWID_WRL 1884 0.84
# 25  World  OWID_WRL 1885 0.88
# 26  World  OWID_WRL 1886 0.71
# 27  World  OWID_WRL 1887 0.67
# 28  World  OWID_WRL 1888 0.88
# 29  World  OWID_WRL 1889 0.94
# 30  World  OWID_WRL 1890 0.87
# ... ...    ...      ...  ...
# 130 World  OWID_WRL 1990  23.72582
# 131 World  OWID_WRL 1991  20.00091
# 132 World  OWID_WRL 1992  19.32084
# 133 World  OWID_WRL 1993  16.97163
# 134 World  OWID_WRL 1994  15.81763
# 135 World  OWID_WRL 1995  17.01668
# 136 World  OWID_WRL 1996  20.66849
# 137 World  OWID_WRL 1997  19.09259
# 138 World  OWID_WRL 1998  12.71566
# 139 World  OWID_WRL 1999  17.97008
# 140 World  OWID_WRL 2000  28.49545
# 141 World  OWID_WRL 2001  24.44389
# 142 World  OWID_WRL 2002  25.02326
# 143 World  OWID_WRL 2003  28.83070
# 144 World  OWID_WRL 2004  38.26500
# 145 World  OWID_WRL 2005  54.52109
# 146 World  OWID_WRL 2006  65.14406
# 147 World  OWID_WRL 2007  72.38908
# 148 World  OWID_WRL 2008  97.25597
# 149 World  OWID_WRL 2009  61.67126
# 150 World  OWID_WRL 2010  79.49553
# 151 World  OWID_WRL 2011 111.25560
# 152 World  OWID_WRL 2012 111.66970
# 153 World  OWID_WRL 2013 108.65852
# 154 World  OWID_WRL 2014  98.94601
# 155 World  OWID_WRL 2015  52.38676
# 156 World  OWID_WRL 2016  43.73417
# 157 World  OWID_WRL 2017  54.19244
# 158 World  OWID_WRL 2018  71.31006
# 159 World  OWID_WRL 2019  64.21057

# %% [markdown]
# ## Data analysis

# %% [markdown]
# ### 2.2) Plot of oil price vs year

# %%
plot(oil$Year, oil$OilPrice, type="b", col="red")
title("Oil Price vs Year")
# Out:
# Plot with title "Oil Price vs Year"

# %% [markdown]
# ### 2.3) Maximum price ever reached
# We employ the strategy used in the Loch exercise; namely, we use a combination of the `max` and `which.max` functions to find our answer.

# %%
message <- c("The highest price was reached in", oil$Year[which.max(oil$OilPrice)],
             "and it amounted to", max(oil$OilPrice), "dollars")
print(paste(message, sep=" ", collapse=" "))
# Out:
# [1] "The highest price was reached in 2012 and it amounted to 111.669702380952 dollars"

# %% [markdown]
# ### 2.4) Forward derivative computation & plot
# The `diff` function is all we need! The only detail to be addressed with care is that `diff` yields a vector which is one element shorter than `oil$Year`; a simple solution is to padd our new vector with a 0 at the beginning (we choose this value at this position because it approximately makes sense if we inspect the previous plot, but this is an arbitrary decision nonetheless).

# %%
derivative <- c(0,diff(oil$OilPrice))
plot(oil$Year, derivative, type="b", col="blue")
title("Numerical derivative of Oil Price vs Year")
# Out:
# Plot with title "Numerical derivative of Oil Price vs Year"

# %% [markdown]
# # Exercise 3: World coal production

# %% [markdown]
# ## 3.1) Loading the data
# This time we want to create a tibble object instead of a dataframe; to import the data, therefore, we have at least to possible ways to proceed:
# - we import the data using `read.csv` in a dataframe as above and then convert to a tibble using `tibble`;
# - we skip the dataframe as an intermidiate step and immediately create a tibble using `read_csv`.
#
# Either is fine.

# %%
url <- "https://drive.google.com/u/0/uc?id=10kgRQGKEC81QoVW9kj8goNzzyLcT0xld&export=download" # once again: slightly modified
#coal <- tibble(read.csv(url)) # alternative 1
coal <- read_csv(url) # alternative 2. Notice that is somewhat smarter, in that with no further arguments if we import with
# read_csv the last column's name is automatically formatted in the correct way (whitespaces are left as in the original csv,
# whereas read.csv replaces them with .).
coal
# Out:
# -- Column specification ------------------------------------------------------------------------------------------------
# cols(
#   Entity = col_character(),
#   Code = col_character(),
#   Year = col_double(),
#   `Coal production (TWh)` = col_double()
# )
#       Entity      Code Year Coal production (TWh)
# 1     Afghanistan AFG  1900 0
# 2     Afghanistan AFG  1901 0
# 3     Afghanistan AFG  1902 0
# 4     Afghanistan AFG  1903 0
# 5     Afghanistan AFG  1904 0
# 6     Afghanistan AFG  1905 0
# 7     Afghanistan AFG  1906 0
# 8     Afghanistan AFG  1907 0
# 9     Afghanistan AFG  1908 0
# 10    Afghanistan AFG  1909 0
# 11    Afghanistan AFG  1910 0
# 12    Afghanistan AFG  1911 0
# 13    Afghanistan AFG  1912 0
# 14    Afghanistan AFG  1913 0
# 15    Afghanistan AFG  1914 0
# 16    Afghanistan AFG  1915 0
# 17    Afghanistan AFG  1916 0
# 18    Afghanistan AFG  1917 0
# 19    Afghanistan AFG  1918 0
# 20    Afghanistan AFG  1919 0
# 21    Afghanistan AFG  1920 0
# 22    Afghanistan AFG  1921 0
# 23    Afghanistan AFG  1922 0
# 24    Afghanistan AFG  1923 0
# 25    Afghanistan AFG  1924 0
# 26    Afghanistan AFG  1925 0
# 27    Afghanistan AFG  1926 0
# 28    Afghanistan AFG  1927 0
# 29    Afghanistan AFG  1928 0
# 30    Afghanistan AFG  1929 0
# ...   ...         ...  ...  ...
# 11499 Zimbabwe    ZWE  1990 41.245
# 11500 Zimbabwe    ZWE  1991 42.145
# 11501 Zimbabwe    ZWE  1992 41.620
# 11502 Zimbabwe    ZWE  1993 39.670
# 11503 Zimbabwe    ZWE  1994 41.020
# 11504 Zimbabwe    ZWE  1995 41.545
# 11505 Zimbabwe    ZWE  1996 38.770
# 11506 Zimbabwe    ZWE  1997 39.745
# 11507 Zimbabwe    ZWE  1998 41.020
# 11508 Zimbabwe    ZWE  1999 37.345
# 11509 Zimbabwe    ZWE  2000 33.071
# 11510 Zimbabwe    ZWE  2001 33.831
# 11511 Zimbabwe    ZWE  2002 29.532
# 11512 Zimbabwe    ZWE  2003 21.180
# 11513 Zimbabwe    ZWE  2004 28.479
# 11514 Zimbabwe    ZWE  2005 25.278
# 11515 Zimbabwe    ZWE  2006 15.801
# 11516 Zimbabwe    ZWE  2007 15.600
# 11517 Zimbabwe    ZWE  2008 11.317
# 11518 Zimbabwe    ZWE  2009 12.503
# 11519 Zimbabwe    ZWE  2010 20.009
# 11520 Zimbabwe    ZWE  2011 19.213
# 11521 Zimbabwe    ZWE  2012 11.950
# 11522 Zimbabwe    ZWE  2013 23.353
# 11523 Zimbabwe    ZWE  2014 43.364
# 11524 Zimbabwe    ZWE  2015 32.517
# 11525 Zimbabwe    ZWE  2016 20.260
# 11526 Zimbabwe    ZWE  2017 21.957
# 11527 Zimbabwe    ZWE  2018 26.910
# 11528 Zimbabwe    ZWE  2019 17.487

# %%
#we modify the first & last columns' names to make typing easier
names(coal)[c(1,4)] <- c("Country","TWh")
coal
# Out:
#       Country     Code Year TWh
# 1     Afghanistan AFG  1900 0
# 2     Afghanistan AFG  1901 0
# 3     Afghanistan AFG  1902 0
# 4     Afghanistan AFG  1903 0
# 5     Afghanistan AFG  1904 0
# 6     Afghanistan AFG  1905 0
# 7     Afghanistan AFG  1906 0
# 8     Afghanistan AFG  1907 0
# 9     Afghanistan AFG  1908 0
# 10    Afghanistan AFG  1909 0
# 11    Afghanistan AFG  1910 0
# 12    Afghanistan AFG  1911 0
# 13    Afghanistan AFG  1912 0
# 14    Afghanistan AFG  1913 0
# 15    Afghanistan AFG  1914 0
# 16    Afghanistan AFG  1915 0
# 17    Afghanistan AFG  1916 0
# 18    Afghanistan AFG  1917 0
# 19    Afghanistan AFG  1918 0
# 20    Afghanistan AFG  1919 0
# 21    Afghanistan AFG  1920 0
# 22    Afghanistan AFG  1921 0
# 23    Afghanistan AFG  1922 0
# 24    Afghanistan AFG  1923 0
# 25    Afghanistan AFG  1924 0
# 26    Afghanistan AFG  1925 0
# 27    Afghanistan AFG  1926 0
# 28    Afghanistan AFG  1927 0
# 29    Afghanistan AFG  1928 0
# 30    Afghanistan AFG  1929 0
# ...   ...         ...  ...  ...
# 11499 Zimbabwe    ZWE  1990 41.245
# 11500 Zimbabwe    ZWE  1991 42.145
# 11501 Zimbabwe    ZWE  1992 41.620
# 11502 Zimbabwe    ZWE  1993 39.670
# 11503 Zimbabwe    ZWE  1994 41.020
# 11504 Zimbabwe    ZWE  1995 41.545
# 11505 Zimbabwe    ZWE  1996 38.770
# 11506 Zimbabwe    ZWE  1997 39.745
# 11507 Zimbabwe    ZWE  1998 41.020
# 11508 Zimbabwe    ZWE  1999 37.345
# 11509 Zimbabwe    ZWE  2000 33.071
# 11510 Zimbabwe    ZWE  2001 33.831
# 11511 Zimbabwe    ZWE  2002 29.532
# 11512 Zimbabwe    ZWE  2003 21.180
# 11513 Zimbabwe    ZWE  2004 28.479
# 11514 Zimbabwe    ZWE  2005 25.278
# 11515 Zimbabwe    ZWE  2006 15.801
# 11516 Zimbabwe    ZWE  2007 15.600
# 11517 Zimbabwe    ZWE  2008 11.317
# 11518 Zimbabwe    ZWE  2009 12.503
# 11519 Zimbabwe    ZWE  2010 20.009
# 11520 Zimbabwe    ZWE  2011 19.213
# 11521 Zimbabwe    ZWE  2012 11.950
# 11522 Zimbabwe    ZWE  2013 23.353
# 11523 Zimbabwe    ZWE  2014 43.364
# 11524 Zimbabwe    ZWE  2015 32.517
# 11525 Zimbabwe    ZWE  2016 20.260
# 11526 Zimbabwe    ZWE  2017 21.957
# 11527 Zimbabwe    ZWE  2018 26.910
# 11528 Zimbabwe    ZWE  2019 17.487

# %% [markdown]
# ## Data analysis

# %% [markdown]
# ### 3.2.1) Number & occurrences of available countries
# The `unique` function applied to the Country column trivially lets us find unique countries and therefore their number via the `length` function.
# Computing the number of entries associated to each country is slightly more involved, and of the many possible solutions to be found online I show two. First solution: we use the `table` function to create a table object - which contains the couples (country, number of occurrences) - which we cast to array; then we recover the country names we just threw away by re-assigning them thanks to the unique dataframe.

# %%
countries <- unique(coal$Country)
n.countries <- length(countries) # I find it useful here to be a little redundant with variables 
message <- c("The number of unique contries whose data is available is", n.countries)
print(paste(message,sep=" ",collapse=" "))
#countries
# Out:
# [1] "The number of unique contries whose data is available is 200"

# %%
#this table tells us how many time each country appears in the Country column of the coal tibble
n.occurrences <- table(coal$Country)
n.occurrences
# Out:
#                      Afghanistan                           Africa
#                              117                              104
#                          Albania                          Algeria
#                              117                               65
#                   American Samoa              Antigua and Barbuda
#                               37                               37
#                        Argentina                          Armenia
#                               65                               25
#                            Aruba                 Asia and Oceania
#                               31                              117
#                     Asia Pacific                        Australia
#                               39                              104
#                          Austria                          Bahamas
#                               65                               37
#                         Barbados                          Belgium
#                               37                               65
#                           Belize                            Benin
#                               37                               37
#                          Bermuda                           Bhutan
#                               37                               37
#           Bosnia and Herzegovina                         Botswana
#                               25                              117
#                           Brazil           British Virgin Islands
#                              104                               37
#                         Bulgaria                     Burkina Faso
#                              104                               37
#                            Burma                          Burundi
#                              117                              117
#                         Cambodia                         Cameroon
#                               37                               37
#                           Canada                       Cape Verde
#                              104                               37
#                   Cayman Islands         Central African Republic
#                               37                               37
#        Central and South America                            Chile
#                              117                               65
#                            China                              CIS
#                              104                               39
#                         Colombia                          Comoros
#                              104                               37
#                     Cook Islands                       Costa Rica
#                               37                               15
#                             Cuba                          Czechia
#                               15                               39
#                   Czechoslovakia     Democratic Republic of Congo
#                               93                               95
#                          Denmark                         Djibouti
#                               65                               37
#                         Dominica               Dominican Republic
#                               37                               37
#                      El Salvador                Equatorial Guinea
#                               18                               11
#                          Eritrea                         Eswatini
#                               23                              117
#                         Ethiopia                            EU-28
#                               18                              117
#                          Eurasia                           Europe
#                              117                              104
#                   Europe (other)                   Faeroe Islands
#                               39                               37
#                 Falkland Islands                             Fiji
#                               37                               37
#                           France                    French Guiana
#                               65                               37
#                 French Polynesia                           Gambia
#                               37                               37
#                          Georgia                          Germany
#                               25                              104
#                            Ghana                        Gibraltar
#                               37                               37
#                           Greece                        Greenland
#                              104                              117
#                          Grenada                       Guadeloupe
#                               37                               37
#                             Guam                        Guatemala
#                               37                               18
#                           Guinea                    Guinea-Bissau
#                               37                               37
#                           Guyana                            Haiti
#                               37                               37
#                         Honduras                          Hungary
#                               14                              104
#                             Inde                            India
#                               80                              104
#                        Indonesia                             Iran
#                              104                               65
#                          Ireland                            Italy
#                               65                               65
#                      Ivory Coast                          Jamaica
#                               37                               37
#                            Japan                           Jordan
#                              104                               16
#                       Kazakhstan                            Kenya
#                               35                               18
#                         Kiribati                           Kosovo
#                               37                                9
#                       Kyrgyzstan                             Laos
#                               25                               37
#                          Lebanon                          Lesotho
#                               37                               37
#                          Liberia                            Macau
#                               37                               37
#                       Madagascar                           Malawi
#                               95                               37
#                         Malaysia                         Maldives
#                               65                               37
#                             Mali                            Malta
#                               37                               37
#                       Martinique                       Mauritania
#                               37                               37
#                        Mauritius                           Mexico
#                               37                              104
#                      Middle East                          Moldova
#                              104                               25
#                         Mongolia                       Montenegro
#                              120                               11
#                       Montserrat                          Morocco
#                               37                               65
#                       Mozambique                          Namibia
#                              112                               27
#                            Nauru                            Nepal
#                               37                              117
#                      Netherlands             Netherlands Antilles
#                               65                               31
#                    New Caledonia                      New Zealand
#                               15                               39
#                        Nicaragua                            Niger
#                               18                              117
#                          Nigeria                             Niue
#                               65                               37
#                    North America                      North Korea
#                              104                              117
#         Northern Mariana Islands                           Norway
#                               37                               65
#                             OECD                             OPEC
#                              109                              117
#                     Other Africa             Other Asia & Pacific
#                               39                               39
#                        Other CIS         Other S. & Cent. America
#                               35                               39
#                         Pakistan                        Palestine
#                              104                               20
#                           Panama                         Paraguay
#                               37                               37
#                     Persian Gulf                             Peru
#                              117                               65
#                      Philippines                           Poland
#                               65                              104
#                         Portugal                      Puerto Rico
#                               65                               37
#                          Reunion                          Romania
#                               37                              104
#                           Russia                           Rwanda
#                              115                               37
#                     Saint Helena            Saint Kitts and Nevis
#                               37                               37
#                      Saint Lucia        Saint Pierre and Miquelon
#                               37                               37
# Saint Vincent and the Grenadines                            Samoa
#                               37                               37
#            Sao Tome and Principe                          Senegal
#                               37                               37
#                           Serbia                       Seychelles
#                               28                               37
#                     Sierra Leone                  Solomon Islands
#                               37                               37
#                          Somalia          South & Central America
#                               37                               39
#                     South Africa                      South Korea
#                              104                              104
#                            Spain                         Suriname
#                              104                               37
#                           Sweden                           Taiwan
#                               65                               65
#                       Tajikistan                         Tanzania
#                               25                              117
#                         Thailand                            Timor
#                              104                               14
#                             Togo                            Tonga
#                               37                               37
#                          Tunisia                           Turkey
#                               66                              104
#         Turks and Caicos Islands                           Uganda
#                               37                               37
#                          Ukraine                   United Kingdom
#                               35                              104
#                    United States    United States Pacific Islands
#                              104                               37
#     United States Virgin Islands                          Uruguay
#                               37                               17
#                             USSR                       Uzbekistan
#                                4                               35
#                          Vanuatu                        Venezuela
#                               37                              104
#                          Vietnam                   Western Sahara
#                              104                               37
#                            World                       Yugoslavia
#                               39                               92
#                           Zambia                         Zimbabwe
#                               95                              120

# %%
# we now reassign this variable 
n.occurrences <- as.numeric(n.occurrences) # n.occurrences is now a numeric array containing the numeric part only.
# Since we lost the names we name every element in our new array by exploiting the fact that unique() already gave us exactly
# what we need now (no adjustments are needed since both table and unique are sorted by alphabetical order)
names(n.occurrences) <- countries
n.occurrences

#the result should be the same one can obtain in python by using:
#import pandas as pd
#pd.read_csv(url).groupby("Entity").nunique().Year
# Out:
#                      Afghanistan                           Africa
#                              117                              104
#                          Albania                          Algeria
#                              117                               65
#                   American Samoa              Antigua and Barbuda
#                               37                               37
#                        Argentina                          Armenia
#                               65                               25
#                            Aruba                     Asia Pacific
#                               31                              117
#                 Asia and Oceania                        Australia
#                               39                              104
#                          Austria                          Bahamas
#                               65                               37
#                         Barbados                          Belgium
#                               37                               65
#                           Belize                            Benin
#                               37                               37
#                          Bermuda                           Bhutan
#                               37                               37
#           Bosnia and Herzegovina                         Botswana
#                               25                              117
#                           Brazil           British Virgin Islands
#                              104                               37
#                         Bulgaria                     Burkina Faso
#                              104                               37
#                            Burma                          Burundi
#                              117                              117
#                              CIS                         Cambodia
#                               37                               37
#                         Cameroon                           Canada
#                              104                               37
#                       Cape Verde                   Cayman Islands
#                               37                               37
#         Central African Republic        Central and South America
#                              117                               65
#                            Chile                            China
#                              104                               39
#                         Colombia                          Comoros
#                              104                               37
#                     Cook Islands                       Costa Rica
#                               37                               15
#                             Cuba                          Czechia
#                               15                               39
#                   Czechoslovakia     Democratic Republic of Congo
#                               93                               95
#                          Denmark                         Djibouti
#                               65                               37
#                         Dominica               Dominican Republic
#                               37                               37
#                            EU-28                      El Salvador
#                               18                               11
#                Equatorial Guinea                          Eritrea
#                               23                              117
#                         Eswatini                         Ethiopia
#                               18                              117
#                          Eurasia                           Europe
#                              117                              104
#                   Europe (other)                   Faeroe Islands
#                               39                               37
#                 Falkland Islands                             Fiji
#                               37                               37
#                           France                    French Guiana
#                               65                               37
#                 French Polynesia                           Gambia
#                               37                               37
#                          Georgia                          Germany
#                               25                              104
#                            Ghana                        Gibraltar
#                               37                               37
#                           Greece                        Greenland
#                              104                              117
#                          Grenada                       Guadeloupe
#                               37                               37
#                             Guam                        Guatemala
#                               37                               18
#                           Guinea                    Guinea-Bissau
#                               37                               37
#                           Guyana                            Haiti
#                               37                               37
#                         Honduras                          Hungary
#                               14                              104
#                             Inde                            India
#                               80                              104
#                        Indonesia                             Iran
#                              104                               65
#                          Ireland                            Italy
#                               65                               65
#                      Ivory Coast                          Jamaica
#                               37                               37
#                            Japan                           Jordan
#                              104                               16
#                       Kazakhstan                            Kenya
#                               35                               18
#                         Kiribati                           Kosovo
#                               37                                9
#                       Kyrgyzstan                             Laos
#                               25                               37
#                          Lebanon                          Lesotho
#                               37                               37
#                          Liberia                            Macau
#                               37                               37
#                       Madagascar                           Malawi
#                               95                               37
#                         Malaysia                         Maldives
#                               65                               37
#                             Mali                            Malta
#                               37                               37
#                       Martinique                       Mauritania
#                               37                               37
#                        Mauritius                           Mexico
#                               37                              104
#                      Middle East                          Moldova
#                              104                               25
#                         Mongolia                       Montenegro
#                              120                               11
#                       Montserrat                          Morocco
#                               37                               65
#                       Mozambique                          Namibia
#                              112                               27
#                            Nauru                            Nepal
#                               37                              117
#                      Netherlands             Netherlands Antilles
#                               65                               31
#                    New Caledonia                      New Zealand
#                               15                               39
#                        Nicaragua                            Niger
#                               18                              117
#                          Nigeria                             Niue
#                               65                               37
#                    North America                      North Korea
#                              104                              117
#         Northern Mariana Islands                           Norway
#                               37                               65
#                             OECD                             OPEC
#                              109                              117
#                     Other Africa             Other Asia & Pacific
#                               39                               39
#                        Other CIS         Other S. & Cent. America
#                               35                               39
#                         Pakistan                        Palestine
#                              104                               20
#                           Panama                         Paraguay
#                               37                               37
#                     Persian Gulf                             Peru
#                              117                               65
#                      Philippines                           Poland
#                               65                              104
#                         Portugal                      Puerto Rico
#                               65                               37
#                          Reunion                          Romania
#                               37                              104
#                           Russia                           Rwanda
#                              115                               37
#                     Saint Helena            Saint Kitts and Nevis
#                               37                               37
#                      Saint Lucia        Saint Pierre and Miquelon
#                               37                               37
# Saint Vincent and the Grenadines                            Samoa
#                               37                               37
#            Sao Tome and Principe                          Senegal
#                               37                               37
#                           Serbia                       Seychelles
#                               28                               37
#                     Sierra Leone                  Solomon Islands
#                               37                               37
#                          Somalia          South & Central America
#                               37                               39
#                     South Africa                      South Korea
#                              104                              104
#                            Spain                         Suriname
#                              104                               37
#                           Sweden                           Taiwan
#                               65                               65
#                       Tajikistan                         Tanzania
#                               25                              117
#                         Thailand                            Timor
#                              104                               14
#                             Togo                            Tonga
#                               37                               37
#                          Tunisia                           Turkey
#                               66                              104
#         Turks and Caicos Islands                             USSR
#                               37                               37
#                           Uganda                          Ukraine
#                               35                              104
#                   United Kingdom                    United States
#                              104                               37
#    United States Pacific Islands     United States Virgin Islands
#                               37                               17
#                          Uruguay                       Uzbekistan
#                                4                               35
#                          Vanuatu                        Venezuela
#                               37                              104
#                          Vietnam                   Western Sahara
#                              104                               37
#                            World                       Yugoslavia
#                               39                               92
#                           Zambia                         Zimbabwe
#                               95                              120

# %% [markdown]
# Second solution: we can group our "coal" dataframe by country and then use the count function to obtain a dataframe (instead of a named vector) which contains two columns: the countries and the number of occurrences.

# %%
n.occurrences2 <- coal %>% group_by(Country) %>% count()
n.occurrences2
# Out:
#     Country                       n
# 1   Afghanistan                   117
# 2   Africa                        104
# 3   Albania                       117
# 4   Algeria                        65
# 5   American Samoa                 37
# 6   Antigua and Barbuda            37
# 7   Argentina                      65
# 8   Armenia                        25
# 9   Aruba                          31
# 10  Asia and Oceania              117
# 11  Asia Pacific                   39
# 12  Australia                     104
# 13  Austria                        65
# 14  Bahamas                        37
# 15  Barbados                       37
# 16  Belgium                        65
# 17  Belize                         37
# 18  Benin                          37
# 19  Bermuda                        37
# 20  Bhutan                         37
# 21  Bosnia and Herzegovina         25
# 22  Botswana                      117
# 23  Brazil                        104
# 24  British Virgin Islands         37
# 25  Bulgaria                      104
# 26  Burkina Faso                   37
# 27  Burma                         117
# 28  Burundi                       117
# 29  Cambodia                       37
# 30  Cameroon                       37
# ... ...                           ...
# 171 Spain                         104
# 172 Suriname                       37
# 173 Sweden                         65
# 174 Taiwan                         65
# 175 Tajikistan                     25
# 176 Tanzania                      117
# 177 Thailand                      104
# 178 Timor                          14
# 179 Togo                           37
# 180 Tonga                          37
# 181 Tunisia                        66
# 182 Turkey                        104
# 183 Turks and Caicos Islands       37
# 184 Uganda                         37
# 185 Ukraine                        35
# 186 United Kingdom                104
# 187 United States                 104
# 188 United States Pacific Islands  37
# 189 United States Virgin Islands   37
# 190 Uruguay                        17
# 191 USSR                            4
# 192 Uzbekistan                     35
# 193 Vanuatu                        37
# 194 Venezuela                     104
# 195 Vietnam                       104
# 196 Western Sahara                 37
# 197 World                          39
# 198 Yugoslavia                     92
# 199 Zambia                         95
# 200 Zimbabwe                      120

# %%
# how can we check whether these two methods yield the same result? One possible way is to count how many TRUE elements there are in the boolean vector n.occurrences2 == n.occurrences;
# if there are as many true elements as there are unique countries then this means that every element of the logical vector is TRUE, and therefore that these 2 vectors are indeed equal everywhere!
library("Matrix")
nnzero(n.occurrences2$n == n.occurrences) == n.countries
# Out:
# Attaching package: 'Matrix'
#
#
# The following objects are masked from 'package:tidyr':
#
#     expand, pack, unpack
# [1] TRUE

# %% [markdown]
# ### 3.2.2) Barplot

# %%
# once we have the named vectors of the count for each country we can trivially use the barplot function
barplot(n.occurrences, col="lightblue") # this isn't really a human readable plot...
title("Number of entries per country")
# Out:
# Plot with title "Number of entries per country"

# %%
barplot(n.occurrences[1:10], col="lightblue") # with less countries it is much more readable
title("Number of entries per country")
# Out:
# Plot with title "Number of entries per country"

# %% [markdown]
# ### 3.3) Total production
# While working on this exercise I discovered why using the specialized function provided by the R packages makes code faster and much easier to read; to tell this story of discovery I'm reporting 2 solutions (the first is long and ugly because it only uses basic logical indexing, the second is short and elegant because it uses `filter` and `aggregate`).
#
# **Solution 1**:
# We first select the years $\geq 1970$ with the help of logical indexing and save the result in a separate tibble (redundant but helpful step); after this we create a named array such that each (name,value) pair represents each country and its cumulative TWh value (we already know each unique country present in the tibble), and by looping over this array we can populate it with the sum of all tibble rows associated with a particular country.

# %%
indices <- coal$Year > 1969 # the boolean vector to be used to subset tibbles
coal.1970 <- coal[indices,] # watch out for that comma: without it R assumes we want to index the columns, which of course
# doesn't work

#coal.1970
print(sprintf("Number of unique country whose data starting from 1970 is available: %d", length(unique(coal.1970$Country))))
# Notice that in the original dataframe we had 200 countries, but it seems that for 21 of them no data is available after 1969 (something which is easily confirmed by inspection). 
# Which countries are we talking about?
missing.countries <- setdiff(countries, coal.1970$Country) # this returns elements which are in countries but not in coal.1970$Country
print("Countries whose data after 1969 is unavailable:")
print(missing.countries)
print("This means that these countries either stopped burning coal after 1969 or that they stopped reporting measurements to OWID")
# Due to above it's a good idea to modify the final cumulative power dataframe in such a way that these countries have NA as their value

# Now we create the actual vector containing the cumulative power produced by each country starting from 1970
power <- rep(0, times = n.countries) # we initialize our array to n.countries zeros

for (i in 1:n.countries) { # this loop is ugly and inefficient
    power[i] <- sum(coal.1970$TWh[coal.1970$Country == countries[i]])
}

names(power) <- countries

# now we put NA in the right places 
power[missing.countries] <- NA
# Without this step the countries in missing.countries will have 0 as their cumulative power. If data relative to these countries is missing because they stopped burning coal 
# then leaving 0 is correct, but since we cannot be sure (especially since there are countries with power = 0 whose data is indeed available) I'd rather put NA in these rows

# we cast power to dataframe to make it easier to print
power.df <- data.frame(power)
# Now we turn the index column into a proper Country column
power.df["Country"] <- countries
row.names(power.df) <- NULL
power.df <- power.df[c("Country", "power")]
names(power.df)[2] <- "Cumulative power"

power.df
# Out:
# [1] "Number of unique country whose data starting from 1970 is available: 179"
# [1] "Countries whose data after 1969 is unavailable:"
#  [1] "Algeria"     "Argentina"   "Austria"     "Belgium"     "Chile"
#  [6] "Denmark"     "France"      "Iran"        "Ireland"     "Italy"
# [11] "Malaysia"    "Morocco"     "Netherlands" "Nigeria"     "Norway"
# [16] "Peru"        "Philippines" "Portugal"    "Sweden"      "Taiwan"
# [21] "Tunisia"
# [1] "This means that these countries either stopped burning coal after 1969 or that they stopped reporting measurements to OWID"
#     Country                       Cumulative power
# 1   Afghanistan                       83.102
# 2   Africa                         57836.224
# 3   Albania                          101.490
# 4   Algeria                               NA
# 5   American Samoa                     0.000
# 6   Antigua and Barbuda                0.000
# 7   Argentina                             NA
# 8   Armenia                            0.000
# 9   Aruba                              0.000
# 10  Asia Pacific                  690240.475
# 11  Asia and Oceania              685960.037
# 12  Australia                      83077.065
# 13  Austria                               NA
# 14  Bahamas                            0.000
# 15  Barbados                           0.000
# 16  Belgium                               NA
# 17  Belize                             0.000
# 18  Benin                              0.000
# 19  Bermuda                            0.000
# 20  Bhutan                             9.400
# 21  Bosnia and Herzegovina           573.077
# 22  Botswana                         221.976
# 23  Brazil                          1252.920
# 24  British Virgin Islands             0.000
# 25  Bulgaria                        2292.632
# 26  Burkina Faso                       0.000
# 27  Burma                             73.596
# 28  Burundi                            0.087
# 29  CIS                           100361.568
# 30  Cambodia                           0.000
# ... ...                           ...
# 171 Spain                            3390.900
# 172 Suriname                            0.000
# 173 Sweden                                 NA
# 174 Taiwan                                 NA
# 175 Tajikistan                         43.776
# 176 Tanzania                           14.361
# 177 Thailand                         1883.332
# 178 Timor                               0.000
# 179 Togo                                0.000
# 180 Tonga                               0.000
# 181 Tunisia                                NA
# 182 Turkey                           5858.687
# 183 Turks and Caicos Islands            0.000
# 184 USSR                            16160.953
# 185 Uganda                              0.000
# 186 Ukraine                         18400.635
# 187 United Kingdom                  13462.307
# 188 United States                  226068.837
# 189 United States Pacific Islands       0.000
# 190 United States Virgin Islands        0.000
# 191 Uruguay                             0.000
# 192 Uzbekistan                        445.960
# 193 Vanuatu                             0.000
# 194 Venezuela                        1066.806
# 195 Vietnam                          5458.324
# 196 Western Sahara                      0.000
# 197 World                         1260113.241
# 198 Yugoslavia                       3834.020
# 199 Zambia                            108.223
# 200 Zimbabwe                         1410.068

# %% [markdown]
# **Solution 2**:
# This time we select years $\geq 1970$ using `filter`, then group by country and compute the sum with `aggregate`; not only is this conceptually clearer, shorter and easy to read, but it's also fully vectorized (no loops) - and therefore much better.

# %%
# We filter coal by rows with year > 1969, extract the TWh column, group it by the Country color of the same filtered dataframe and finally apply the sum function in each group.
power.df.2 <- aggregate(filter(coal, Year > 1969)$TWh, by = list(filter(coal, Year > 1969)$Country), FUN = sum) # 1 line, vectorized and the result is a dataframe already
names(power.df.2) <- c("Country", "Cumulative power")

# The result of this is already a dataframe, but it's missing the rows with Country equal to missing.countries since they're obviously absent from filter(coal, Year > 1969).
# We can add them back using rbind by creating a dataframe containing the rows to add
missing.countries.df <- data.frame(missing.countries, rep(NA, times = length(missing.countries)))
names(missing.countries.df) <- c("Country", "Cumulative power")
power.df.2 <- rbind(power.df.2, missing.countries.df)
# rbind returns a dataframe which is not in alphabetical order anymore; this is easily fixed if we sort via order()
power.df.2 <- power.df.2[order(power.df.2$Country),]
# Finally we remove row names this way (otherwise we will see a column containing the shuffled indices)
row.names(power.df.2) <- NULL

power.df.2
# Out:
#     Country                       Cumulative power
# 1   Afghanistan                       83.102
# 2   Africa                         57836.224
# 3   Albania                          101.490
# 4   Algeria                               NA
# 5   American Samoa                     0.000
# 6   Antigua and Barbuda                0.000
# 7   Argentina                             NA
# 8   Armenia                            0.000
# 9   Aruba                              0.000
# 10  Asia and Oceania              685960.037
# 11  Asia Pacific                  690240.475
# 12  Australia                      83077.065
# 13  Austria                               NA
# 14  Bahamas                            0.000
# 15  Barbados                           0.000
# 16  Belgium                               NA
# 17  Belize                             0.000
# 18  Benin                              0.000
# 19  Bermuda                            0.000
# 20  Bhutan                             9.400
# 21  Bosnia and Herzegovina           573.077
# 22  Botswana                         221.976
# 23  Brazil                          1252.920
# 24  British Virgin Islands             0.000
# 25  Bulgaria                        2292.632
# 26  Burkina Faso                       0.000
# 27  Burma                             73.596
# 28  Burundi                            0.087
# 29  Cambodia                           0.000
# 30  Cameroon                           0.000
# ... ...                           ...
# 171 Spain                            3390.900
# 172 Suriname                            0.000
# 173 Sweden                                 NA
# 174 Taiwan                                 NA
# 175 Tajikistan                         43.776
# 176 Tanzania                           14.361
# 177 Thailand                         1883.332
# 178 Timor                               0.000
# 179 Togo                                0.000
# 180 Tonga                               0.000
# 181 Tunisia                                NA
# 182 Turkey                           5858.687
# 183 Turks and Caicos Islands            0.000
# 184 Uganda                              0.000
# 185 Ukraine                         18400.635
# 186 United Kingdom                  13462.307
# 187 United States                  226068.837
# 188 United States Pacific Islands       0.000
# 189 United States Virgin Islands        0.000
# 190 Uruguay                             0.000
# 191 USSR                            16160.953
# 192 Uzbekistan                        445.960
# 193 Vanuatu                             0.000
# 194 Venezuela                        1066.806
# 195 Vietnam                          5458.324
# 196 Western Sahara                      0.000
# 197 World                         1260113.241
# 198 Yugoslavia                       3834.020
# 199 Zambia                            108.223
# 200 Zimbabwe                         1410.068

# %% [markdown]
# To see which countries are burning the most coal we can sort the "power" array in decreasing order, then pick its first 5 elements - excluding the first one, which is "World" and therefore is arguably to be excluded.

# %%
sorted_power <- sort(power, dec=TRUE)
top_5_countries_TWh <- sorted_power[2:6] #sorted_power[1] is the whole world, which isn't a single country
top_5_countries <- names(top_5_countries_TWh) #being a bit redundant with variables here

message <- c("The 5 countries with the most TWh produced are:",top_5_countries,"- with:",top_5_countries_TWh,
             "TWh respectively.")
print(paste(message, sep=" ", collapse=" "))
# Out:
# [1] "The 5 countries with the most TWh produced are: Asia Pacific Asia and Oceania China OECD North America - with: 690240.475 685960.037 459564.647 438441.381 244443.419 TWh respectively."

# %% [markdown]
# ### 3.4) Plot of power vs time
# Now that we know which 5 countries are the "winners" of the coal competition we can extract the relevant rows from the tibble and use them to plot the power produced vs time graph.
# To produce our desidered plot via `ggplot2` we first create a new smaller tibble, only containing the rows corresponding to the top 5 countries selected above (we can create this tibble in multiple ways, see below); then we graph a Years vs TWh plot using Country to produce the label of each time series.

# %%
#To select rows where Country is equal to one of the elements of the top_5_countries array we can proceed in at least 3 ways:

#1) Logical indexing with the %in% operator, which checks whether a certain object is in another:
#coal_plot <- coal[coal$Country %in% top_5_countries,]

#2) "indirect" logical indexing, same as above but with the function is.element checking membership
#coal_plot <- coal[is.element(coal$Country, top_5_countries),]

#3) using filter instead of direct subsetting, with the operator %in% once again:
coal_plot <- filter(coal, Country %in% top_5_countries)
#and so on. It's trivial to check these commands produce the same output.

n_countries_to_plot <- 5

#coal_plot: Year on the x axis, TWh on the y axis, Country to produce time series label and color
g <- ggplot(data = coal_plot, aes(x = Year, y = TWh, col = Country)) + geom_point() + geom_line()
g
# Out:
# plot without title

# %% [markdown]
# ### 3.5) Plot of the cumulative sum of the World's power production vs time
# Here we simply adapt code from part 3.3) and 3.4): we use `cumsum` + logical indexing to compute the desidered "World-only" dataframe.

# %%
world <- coal[coal$Country == "World",] #watch out for the , !
world["cumsum"] <- cumsum(world$TWh)

g <- ggplot(data = world, aes(x = Year, y = cumsum))
g <- g + geom_point()
g <- g + geom_line()
g <- g + labs(x = "Year", y = "cumulative power produced (TWh)")
g <- g + ggtitle("Cumulative power consumption over time of the whole world")
g
# Out:
# plot without title

# %% [markdown]
# # Exercise 4: COVID-19 vaccinations

# %% [markdown]
# ## Loading the data (part 1)

# %%
#url <- "https://github.com/owid/covid-19-data/blob/master/public/data/vaccinations/vaccinations-by-manufacturer.csv"
#it's easier if we use the raw data, i.e. use the url pointing to a web page containing only the desiderd csv
url <- "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations-by-manufacturer.csv"
covid <- read_csv(url)
covid
# Out:
# -- Column specification ------------------------------------------------------------------------------------------------
# cols(
#   location = col_character(),
#   date = col_date(format = ""),
#   vaccine = col_character(),
#   total_vaccinations = col_double()
# )
#      location      date       vaccine         total_vaccinations
# 1    Chile         2020-12-24 Pfizer/BioNTech   420
# 2    Chile         2020-12-25 Pfizer/BioNTech  5198
# 3    Chile         2020-12-26 Pfizer/BioNTech  8338
# 4    Chile         2020-12-27 Pfizer/BioNTech  8649
# 5    Chile         2020-12-28 Pfizer/BioNTech  8649
# 6    Chile         2020-12-29 Pfizer/BioNTech  8649
# 7    Chile         2020-12-30 Pfizer/BioNTech  8649
# 8    Chile         2020-12-31 Pfizer/BioNTech  8649
# 9    Chile         2021-01-01 Pfizer/BioNTech  8649
# ### 4.1) Filtering the data about Italy
# We use the `filter` function to extract the relevant rows (logical indexing is a possible alternative, as we have already seen above).

# %%
#since we'll have to repeat this analysis for Germany and the US it's a good idea to write some functions
extract_location = function(df, loc) {filter(df, location == loc)}

covid.ita <- extract_location(covid, "Italy") #no function alternative: filter(covid, location == "Italy")
#covid.ita <- covid[covid$location == "Italy",] is a simple (still no-function) alternative
covid.ita
# Out:
#     location date       vaccine            total_vaccinations
# 1   Italy    2020-12-27 Pfizer/BioNTech       7152
# 2   Italy    2020-12-28 Pfizer/BioNTech       8573
# 3   Italy    2020-12-29 Pfizer/BioNTech       9578
# 4   Italy    2020-12-30 Pfizer/BioNTech      14304
# 5   Italy    2020-12-31 Pfizer/BioNTech      39776
# 6   Italy    2021-01-01 Pfizer/BioNTech      50827
# 7   Italy    2021-01-02 Pfizer/BioNTech      89330
# 8   Italy    2021-01-03 Pfizer/BioNTech     124464
# 9   Italy    2021-01-04 Pfizer/BioNTech     193093
# 10  Italy    2021-01-05 Pfizer/BioNTech     272629
# 11  Italy    2021-01-06 Pfizer/BioNTech     337802
# 12  Italy    2021-01-07 Pfizer/BioNTech     429961
# 13  Italy    2021-01-08 Moderna                  1
# 14  Italy    2021-01-08 Pfizer/BioNTech     525457
# 15  Italy    2021-01-09 Pfizer/BioNTech     612321
# 16  Italy    2021-01-10 Pfizer/BioNTech     672646
# 17  Italy    2021-01-11 Pfizer/BioNTech     753535
# 18  Italy    2021-01-12 Pfizer/BioNTech     835343
# 19  Italy    2021-01-13 Moderna                  2
# 20  Italy    2021-01-13 Pfizer/BioNTech     929509
# 21  Italy    2021-01-14 Moderna                 86
# 22  Italy    2021-01-14 Pfizer/BioNTech    1022684
# 23  Italy    2021-01-15 Moderna               1180
# 24  Italy    2021-01-15 Pfizer/BioNTech    1110705
# 25  Italy    2021-01-16 Moderna               2090
# 26  Italy    2021-01-16 Pfizer/BioNTech    1174431
# 27  Italy    2021-01-17 Moderna               2383
# 28  Italy    2021-01-17 Pfizer/BioNTech    1210878
# 29  Italy    2021-01-18 Moderna               3601
# 30  Italy    2021-01-18 Pfizer/BioNTech    1252969
# ... ...      ...        ...                ...
# 223 Italy    2021-03-29 Moderna             498522
# 224 Italy    2021-03-29 Oxford/AstraZeneca 1842073
# 225 Italy    2021-03-29 Pfizer/BioNTech    7385465
# 226 Italy    2021-03-30 Moderna             525927
# 227 Italy    2021-03-30 Oxford/AstraZeneca 1911076
# 228 Italy    2021-03-30 Pfizer/BioNTech    7543710
# 229 Italy    2021-03-31 Moderna             547797
# 230 Italy    2021-03-31 Oxford/AstraZeneca 1977616
# 231 Italy    2021-03-31 Pfizer/BioNTech    7750264
# 232 Italy    2021-04-01 Moderna             571284
# 233 Italy    2021-04-01 Oxford/AstraZeneca 2027930
# 234 Italy    2021-04-01 Pfizer/BioNTech    7950939
# 235 Italy    2021-04-02 Moderna             599320
# 236 Italy    2021-04-02 Oxford/AstraZeneca 2086937
# 237 Italy    2021-04-02 Pfizer/BioNTech    8125421
# 238 Italy    2021-04-03 Moderna             632361
# 239 Italy    2021-04-03 Oxford/AstraZeneca 2131200
# 240 Italy    2021-04-03 Pfizer/BioNTech    8266202
# 241 Italy    2021-04-04 Moderna             644082
# 242 Italy    2021-04-04 Oxford/AstraZeneca 2168913
# 243 Italy    2021-04-04 Pfizer/BioNTech    8310821
# 244 Italy    2021-04-05 Moderna             663150
# 245 Italy    2021-04-05 Oxford/AstraZeneca 2226183
# 246 Italy    2021-04-05 Pfizer/BioNTech    8400546
# 247 Italy    2021-04-06 Moderna             699810
# 248 Italy    2021-04-06 Oxford/AstraZeneca 2306012
# 249 Italy    2021-04-06 Pfizer/BioNTech    8553208
# 250 Italy    2021-04-07 Moderna             718470
# 251 Italy    2021-04-07 Oxford/AstraZeneca 2361088
# 252 Italy    2021-04-07 Pfizer/BioNTech    8659266

# %% [markdown]
# ### 4.2) Plot number of vaccines given each day for each vaccine manufacturer
# Here it suffices to recycle the ggplot2 code from above; we split vaccine manufacturers using logical indexing/filter in the same way we did above.

# %%
plot_vaccine_manufacturers <- function(df, loc) {
    #we first create a smaller dataframe with location equal to the given country...
    df.loc <- filter(df, location == loc)
    #...then we plot this new dataframe using ggplot2
    g <- ggplot(data = df.loc, aes(x = date, y = total_vaccinations, col = vaccine)) + geom_point() + geom_line()
    g <- g + labs(x = "date", y = "Total number of vaccinations")
    g <- g + ggtitle(sprintf("Vaccinations vs time in %s",loc))
    g
}

plot_vaccine_manufacturers(covid, "Italy")
# Out:
# plot without title

# %% [markdown]
# ### 4.3) Plot the total number of vaccines per day in Italy
# To perform the aforementioned plot it suffices to modify slightly what was done in the previous exercise - namely, we need to consider (via a sum) the number of vaccines done each day irrespective of their manufacturer.
# To achieve this we rewrite the `plot_vaccine_manufacturers` function by creating a different "intermediate" dataframe using the `aggregate` function, which lets us split the data into subsets of vaccines with the same date and then apply the `sum` function.

# %%
plot_total_number_of_vaccinations <- function(df, loc) {
    #dataframe relative to that location
    df.loc <- filter(df, location == loc)
    #dataframe containing the variable "total number of vaccinations", which is the sum of the total_vaccinations column grouped by date
    df.tot_n <- aggregate(df.loc$total_vaccinations, by = list(df.loc$date), FUN = sum)
    #we rename columns to make typing their names easier
    names(df.tot_n) <- c("date","tot_n_vac")
    
    #now we can plot as usual
    g <- ggplot(data = df.tot_n, aes(x = date, y = tot_n_vac)) + geom_point() + geom_line()
    g <- g + labs(x = "date", y = "total number of vaccinations (all manufacturers)") + ggtitle(sprintf("Total number of vaccines in %s vs time",loc))
    g
}

plot_total_number_of_vaccinations(covid, "Italy")
#metti confronto con groupby per sicurezza ihih
# Out:
# plot without title

# %% [markdown]
# ### 4.4) Repeat the analysis for Germany and the US
# Since we defined a function in each of the previous exercises (points 4.1, 4.2, 4.3) it suffices to call them again with different arguments.

# %%
#point 4.1) for Germany
covid.germany <- extract_location(covid, "Germany")
covid.germany
# Out:
#     location date       vaccine            total_vaccinations
# 1   Germany  2020-12-27 Moderna                 0
# 2   Germany  2020-12-27 Oxford/AstraZeneca      0
# 184 United States 2021-04-04 Pfizer/BioNTech 84810406
# 185 United States 2021-04-05 Johnson&Johnson  4204015
# 186 United States 2021-04-05 Moderna         76791212
# 187 United States 2021-04-05 Pfizer/BioNTech 86041963
# 188 United States 2021-04-06 Johnson&Johnson  4299901
# 189 United States 2021-04-06 Moderna         77285350
# 190 United States 2021-04-06 Pfizer/BioNTech 86855993
# 191 United States 2021-04-07 Johnson&Johnson  4544552
# 192 United States 2021-04-07 Moderna         78315776
# 193 United States 2021-04-07 Pfizer/BioNTech 88463874

# %%
#point 4.2) for Germany
plot_vaccine_manufacturers(covid, "Germany")
# Out:
# plot without title

# %%
#point 4.2) for the US
plot_vaccine_manufacturers(covid, "United States")
# Out:
# plot without title

# %%
#point 4.3) for Germany
plot_total_number_of_vaccinations(covid, "Germany")
# Out:
# plot without title

# %%
#point 4.3) for the US
plot_total_number_of_vaccinations(covid, "United States")
# Out:
# plot without title

# %% [markdown]
# ## Loading the data (part 2)

# %% [markdown]
# We load the data in a tibble in the usual way.

# %%
url <- "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv"
covid2 <- read_csv(url)
covid2
# Out:
# -- Column specification ------------------------------------------------------------------------------------------------
# cols(
#   location = col_character(),
#   iso_code = col_character(),
#   date = col_date(format = ""),
#   total_vaccinations = col_double(),
#   people_vaccinated = col_double(),
#   people_fully_vaccinated = col_double(),
#   daily_vaccinations_raw = col_double(),
#   daily_vaccinations = col_double(),
#   total_vaccinations_per_hundred = col_double(),
#   people_vaccinated_per_hundred = col_double(),
#   people_fully_vaccinated_per_hundred = col_double(),
#   daily_vaccinations_per_million = col_double()
# )
#       location    iso_code date       total_vaccinations people_vaccinated
# 1     Afghanistan AFG      2021-02-22     0                  0
# 2     Afghanistan AFG      2021-02-23    NA                 NA
# 3     Afghanistan AFG      2021-02-24    NA                 NA
# 4     Afghanistan AFG      2021-02-25    NA                 NA
# 5     Afghanistan AFG      2021-02-26    NA                 NA
# 6     Afghanistan AFG      2021-02-27    NA                 NA
# 7     Afghanistan AFG      2021-02-28  8200               8200
# 8     Afghanistan AFG      2021-03-01    NA                 NA
# 9     Afghanistan AFG      2021-03-02    NA                 NA
# 10    Afghanistan AFG      2021-03-03    NA                 NA
# 11    Afghanistan AFG      2021-03-04    NA                 NA
# 12    Afghanistan AFG      2021-03-05    NA                 NA
# 13    Afghanistan AFG      2021-03-06    NA                 NA
# 14    Afghanistan AFG      2021-03-07    NA                 NA
# 15    Afghanistan AFG      2021-03-08    NA                 NA
# 16    Afghanistan AFG      2021-03-09    NA                 NA
# 17    Afghanistan AFG      2021-03-10    NA                 NA
# 18    Afghanistan AFG      2021-03-11    NA                 NA
# 19    Afghanistan AFG      2021-03-12    NA                 NA
# 20    Afghanistan AFG      2021-03-13    NA                 NA
# 21    Afghanistan AFG      2021-03-14    NA                 NA
# 22    Afghanistan AFG      2021-03-15    NA                 NA
# 23    Afghanistan AFG      2021-03-16 54000              54000
# 24    Africa      OWID_AFR 2021-01-09     0                  0
# 16    NA                                  74
# 17    NA                                  74
# 18    NA                                  74
# 19    NA                                  74
# 20    NA                                  74
# 21    NA                                  74
# 22    NA                                  74
# 23    NA                                  74
# 24    NA                                  NA
# 25    NA                                   0
# 26    NA                                   0
# 27    NA                                   0
# 28    NA                                   0
# 29    NA                                   0
# 30    NA                                   0
# ...   ...                                 ...
# 11194   NA                                135
# 11195   NA                                103
# 11196   NA                                 76
# 11197   NA                                 52
# 11198   NA                                 48
# 11199   NA                                 42
# 11200   NA                                 40
# 11201   NA                                 21
# 11202   NA                                 36
# 11203   NA                                 36
# 11204   NA                                 38
# 11205   NA                                 52
# 11206   NA                                 56
# 11207   NA                                 61
# 11208 0.00                                 57
# 11209 0.01                                 54
# 11210 0.02                                118
# 11211 0.03                                182
# 11212 0.04                                250
# 11213 0.05                                300
# 11214 0.07                                350
# 11215 0.08                                366
# 11216 0.09                                391
# 11217 0.10                                384
# 11218 0.12                                445
# 11219 0.14                                549
# 11220 0.14                                572
# 11221 0.15                                574
# 11222 0.15                                614
# 11223 0.16                                738

# %% [markdown]
# ## Data analysis (part 2)

# %% [markdown]
# ### 4.1 bis) Plotting the daily number of vaccinations per million in Europe

# %% [markdown]
# We can extract data relevant to Europe using the same function defined above; then we create a smaller dataframe (containing only the 3 relevant columns) and plot it via ggplot2 (in exactly the same way as above).

# %%
covid.eu <- extract_location(covid2, "Europe")
covid.eu.plot <- covid.eu[c("daily_vaccinations_per_million","date","location")]
#covid.eu.plot

#some rows contain NA, we can use the drop_na function from tidyr to remove them. If we don't ggplot will automatically, but it will give us a warning
g <- ggplot(data = drop_na(covid.eu.plot), aes(x = date, y = daily_vaccinations_per_million, col = location)) + geom_line() + geom_point() + ggtitle("Daily vaccinations per million in Europe")
g
# Out:
# plot without title

# %% [markdown]
# ### 4.2 bis) "Free" analysis

# %% [markdown]
# We can reproduce the above plot but for all continents. We can repeat the same steps but instead of specifying location == Europe we search (via regular expressions) every row with as iso_code starting with OWID_...

# %%
#covid2[str_detect(covid2$iso_code, "^OWID_.*"),]
covid.continents <- covid2[grepl("^OWID_.*", covid2$iso_code),] #this line and the previous one are equivalent, see the documentation
#covid.continents #^OWID_.* means: match any line starting with OWID_ followed by any character (.) 0 or more times (*)
g <- ggplot(data = drop_na(covid.continents), aes(x = total_vaccinations, col = location)) + geom_boxplot()
g
# Out:
# plot without title

# %%
#alternative plot
covid.continents$total_vaccinations[is.na(covid.continents$total_vaccinations)] <- 0
#we remove NA's in order to have a well behaved sum below
covid.continents.barplot <- aggregate(covid.continents$total_vaccinations, by = list(covid.continents$location), FUN = sum)

# we change column names to make everything easier to read
names(covid.continents.barplot) <- c("location","total_vaccinations")

par(mar = c(10, 5, 3, 1)) #to make things easier to read in the x axis

pal <- colorRampPalette(colors = c("deepskyblue", "blue"))(14)
barplot(height = covid.continents.barplot$total_vaccinations , names = covid.continents.barplot$location, las = 2, col = pal) #las=2 --> labels are orthogonal to the axis
title("Total number of vaccinations per continent")
# Out:
# Plot with title "Total number of vaccinations per continent"
